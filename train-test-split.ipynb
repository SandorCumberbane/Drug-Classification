# %% [markdown]
# # Train Test Split

# %% [markdown]
# Libraries:

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# Data Import:

# %%
data = pd.read_csv("data.csv")
data.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# Tidy *Drug* column.

# %%
data["Drug"] = data["Drug"].replace(r"[Dd]rug", "", regex=True)

# %%
data
# Out:
#      Age Sex      BP Cholesterol  Na_to_K Drug
# 0     23   F    HIGH        HIGH   25.355    Y
# 1     47   M     LOW        HIGH   13.093    C
# 2     47   M     LOW        HIGH   10.114    C
# 3     28   F  NORMAL        HIGH    7.798    X
# 4     61   F     LOW        HIGH   18.043    Y
# ..   ...  ..     ...         ...      ...  ...
# 195   56   F     LOW        HIGH   11.567    C
# 196   16   M     LOW        HIGH   12.006    C
# 197   52   M  NORMAL        HIGH    9.894    X
# 198   23   M  NORMAL      NORMAL   14.020    X
# 199   40   F     LOW      NORMAL   11.349    X
#
# [200 rows x 6 columns]

# %% [markdown]
# ### Map ordinal features

# %% [markdown]
# The features *BP* and *Cholesterol* are ordered categorical variables. For our algorithms to work, these must be encoded into integers.

# %%
bp_mapping = {"LOW": 0,
              "NORMAL": 1,
              "HIGH": 2}
cholesterol_mapping = {"NORMAL": 1,
                       "HIGH": 2}

# %%
data_encoded = data.copy()
data_encoded["BP"] = data_encoded["BP"].map(bp_mapping)
data_encoded["Cholesterol"] = data_encoded["Cholesterol"].map(cholesterol_mapping)

# %%
data_encoded
# Out:
#      Age Sex  BP  Cholesterol  Na_to_K Drug
# 0     23   F   2            2   25.355    Y
# 1     47   M   0            2   13.093    C
# 2     47   M   0            2   10.114    C
# 3     28   F   1            2    7.798    X
# 4     61   F   0            2   18.043    Y
# ..   ...  ..  ..          ...      ...  ...
# 195   56   F   0            2   11.567    C
# 196   16   M   0            2   12.006    C
# 197   52   M   1            2    9.894    X
# 198   23   M   1            1   14.020    X
# 199   40   F   0            1   11.349    X
#
# [200 rows x 6 columns]

# %% [markdown]
# ### One-hot encoding of nominal features

# %% [markdown]
# As logistic regression can't take multiple target variables, I will look at two cases. The first case doesn't encode the target, whereas the second does.

# %%
data = pd.get_dummies(data=data_encoded,
                      columns=["Sex"],
                      drop_first=True)
data = data[["Age", "Sex_M", "Cholesterol", "Na_to_K", "Drug"]]
data
# Out:
#      Age  Sex_M  Cholesterol  Na_to_K Drug
# 0     23      0            2   25.355    Y
# 1     47      1            2   13.093    C
# 2     47      1            2   10.114    C
# 3     28      0            2    7.798    X
# 4     61      0            2   18.043    Y
# ..   ...    ...          ...      ...  ...
# 195   56      0            2   11.567    C
# 196   16      1            2   12.006    C
# 197   52      1            2    9.894    X
# 198   23      1            1   14.020    X
# 199   40      0            1   11.349    X
#
# [200 rows x 5 columns]

# %% [markdown]
# The features *Sex* and *Drug* are nominal features (they can't be ordered), thus they are one-hot encoded. To reduce the correlation among the variables, the first feature of the one-hot encoded variables is removed. Here the column Sex_M explains if the patient is male, the drug columns explain which drugs are taken. If all are zero, this means that drug A is taken.

# %%
data_encoded = pd.get_dummies(data=data)

# %%
data_encoded
# Out:
#      Age  Sex_M  Cholesterol  Na_to_K  Drug_A  Drug_B  Drug_C  Drug_X  Drug_Y
# 0     23      0            2   25.355       0       0       0       0       1
# 1     47      1            2   13.093       0       0       1       0       0
# 2     47      1            2   10.114       0       0       1       0       0
# 3     28      0            2    7.798       0       0       0       1       0
# 4     61      0            2   18.043       0       0       0       0       1
# ..   ...    ...          ...      ...     ...     ...     ...     ...     ...
# 195   56      0            2   11.567       0       0       1       0       0
# 196   16      1            2   12.006       0       0       1       0       0
# 197   52      1            2    9.894       0       0       0       1       0
# 198   23      1            1   14.020       0       0       0       1       0
# 199   40      0            1   11.349       0       0       0       1       0
#
# [200 rows x 9 columns]

# %% [markdown]
# ## Train test split

# %% [markdown]
# Before we start, check version of scikit-learn, so that the seed yields same results. Here I have version 1.2.2.

# %%
# !conda list scikit-learn
# Out:
# # packages in environment at /Users/Alexander/opt/anaconda3:
# #
# # Name                    Version                   Build  Channel
# scikit-learn              1.2.2                    pypi_0    pypi

# %%
# !pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.2.2
# Summary: A set of python modules for machine learning and data mining
# Home-page: http://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: /Users/Alexander/opt/anaconda3/lib/python3.9/site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by:

# %% [markdown]
# ### Not encoded target

# %% [markdown]
# Perform train test split with sklearn.

# %%
train, test = train_test_split(data,
                     test_size = 0.2,
                     random_state = 10,
                     stratify = y)

# %% [markdown]
# Check if it worked.

# %%
train
# Out:
#      Age  Sex_M  Cholesterol  Na_to_K Drug
# 57    40      1            2   27.826    Y
# 67    17      1            1   10.832    X
# 69    18      0            1   24.276    Y
# 35    46      1            1    7.285    X
# 8     60      1            2   15.171    Y
# ..   ...    ...          ...      ...  ...
# 54    68      0            1   10.189    B
# 106   22      1            2   11.953    X
# 154   37      1            1   16.724    Y
# 159   34      0            1   12.923    X
# 177   25      1            2   19.011    Y
#
# [160 rows x 5 columns]

# %%
test
# Out:
#      Age  Sex_M  Cholesterol  Na_to_K Drug
# 66    29      1            2   12.856    A
# 48    23      1            2   31.686    Y
# 30    18      0            1    8.750    X
# 62    67      1            1   20.693    Y
# 39    15      1            2    9.084    X
# 108   72      1            1    9.677    B
# 28    39      0            1   22.697    Y
# 68    54      1            2   24.658    Y
# 171   45      1            1   10.017    X
# 127   35      1            1    7.845    X
# 7     41      1            2   11.037    C
# 147   26      0            1   12.307    A
# 150   49      1            1    8.700    A
# 97    56      0            2   25.395    Y
# 193   72      1            2    6.769    C
# 22    47      1            1   30.568    Y
# 165   38      1            2   18.295    Y
# 112   35      1            1    9.170    X
# 89    50      0            1   17.211    Y
# 0     23      0            2   25.355    Y
# 64    60      0            2   13.303    B
# 103   56      1            2    8.966    X
# 65    68      0            1   27.050    Y
# 160   30      0            2   10.443    X
# 155   49      1            2   10.537    C
# 156   31      1            1   11.227    A
# 26    31      1            2   30.366    Y
# 189   64      1            1   20.932    Y
# 77    26      0            1   19.161    Y
# 117   40      0            2   10.103    X
# 131   52      1            1   32.922    Y
# 41    58      0            1   14.239    B
# 109   23      1            2   16.850    Y
# 27    49      0            1    9.381    X
# 79    32      0            1   10.840    X
# 34    53      1            2   14.133    X
# 179   67      0            2   15.891    Y
# 52    62      1            1   27.183    Y
# 178   39      1            2   15.969    Y
# 17    43      1            2   13.972    A

# %% [markdown]
# ### Encoded target

# %% [markdown]
# Perform train test split with sklearn.

# %%
train_encoded, test_encoded = train_test_split(
    data_encoded, test_size=0.2, random_state=10, stratify=y
)

# %% [markdown]
# Check if it worked.

# %%
train_encoded
# Out:
#      Age  Sex_M  Cholesterol  Na_to_K  Drug_A  Drug_B  Drug_C  Drug_X  Drug_Y
# 57    40      1            2   27.826       0       0       0       0       1
# 67    17      1            1   10.832       0       0       0       1       0
# 69    18      0            1   24.276       0       0       0       0       1
# 35    46      1            1    7.285       0       0       0       1       0
# 8     60      1            2   15.171       0       0       0       0       1
# ..   ...    ...          ...      ...     ...     ...     ...     ...     ...
# 54    68      0            1   10.189       0       1       0       0       0
# 106   22      1            2   11.953       0       0       0       1       0
# 154   37      1            1   16.724       0       0       0       0       1
# 159   34      0            1   12.923       0       0       0       1       0
# 177   25      1            2   19.011       0       0       0       0       1
#
# [160 rows x 9 columns]

# %%
test_encoded
# Out:
#      Age  Sex_M  Cholesterol  Na_to_K  Drug_A  Drug_B  Drug_C  Drug_X  Drug_Y
# 66    29      1            2   12.856       1       0       0       0       0
# 48    23      1            2   31.686       0       0       0       0       1
# 30    18      0            1    8.750       0       0       0       1       0
# 62    67      1            1   20.693       0       0       0       0       1
# 39    15      1            2    9.084       0       0       0       1       0
# 108   72      1            1    9.677       0       1       0       0       0
# 28    39      0            1   22.697       0       0       0       0       1
# 68    54      1            2   24.658       0       0       0       0       1
# 171   45      1            1   10.017       0       0       0       1       0
# 127   35      1            1    7.845       0       0       0       1       0
# 7     41      1            2   11.037       0       0       1       0       0
# 147   26      0            1   12.307       1       0       0       0       0
# 150   49      1            1    8.700       1       0       0       0       0
# 97    56      0            2   25.395       0       0       0       0       1
# 193   72      1            2    6.769       0       0       1       0       0
# 22    47      1            1   30.568       0       0       0       0       1
# 165   38      1            2   18.295       0       0       0       0       1
# 112   35      1            1    9.170       0       0       0       1       0
# 89    50      0            1   17.211       0       0       0       0       1
# 0     23      0            2   25.355       0       0       0       0       1
# 64    60      0            2   13.303       0       1       0       0       0
# 103   56      1            2    8.966       0       0       0       1       0
# 65    68      0            1   27.050       0       0       0       0       1
# 160   30      0            2   10.443       0       0       0       1       0
# 155   49      1            2   10.537       0       0       1       0       0
# 156   31      1            1   11.227       1       0       0       0       0
# 26    31      1            2   30.366       0       0       0       0       1
# 189   64      1            1   20.932       0       0       0       0       1
# 77    26      0            1   19.161       0       0       0       0       1
# 117   40      0            2   10.103       0       0       0       1       0
# 131   52      1            1   32.922       0       0       0       0       1
# 41    58      0            1   14.239       0       1       0       0       0
# 109   23      1            2   16.850       0       0       0       0       1
# 27    49      0            1    9.381       0       0       0       1       0
# 79    32      0            1   10.840       0       0       0       1       0
# 34    53      1            2   14.133       0       0       0       1       0
# 179   67      0            2   15.891       0       0       0       0       1
# 52    62      1            1   27.183       0       0       0       0       1
# 178   39      1            2   15.969       0       0       0       0       1
# 17    43      1            2   13.972       1       0       0       0       0

# %% [markdown]
# ## Export

# %% [markdown]
# Export data to csv.

# %%
train.to_csv("train.csv", index=False)
test.to_csv("test.csv", index=False)

# %%
train_encoded.to_csv("train_encoded.csv", index=False)
test_encoded.to_csv("test_encoded.csv", index=False)
